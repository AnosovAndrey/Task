# %% [markdown]
# <a href="https://colab.research.google.com/github/AnosovAndrey/Task/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library
from sklearn.preprocessing import MinMaxScaler
from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv("../content/input/data.csv", header=None)
otrezok=pd.read_csv("../content/input/otrezok.csv", header=None)

# %%
splited_data = np.array_split(data, 301)
splited_otrezok = np.array_split(otrezok, 301)
data_list = list(zip(splited_data, splited_otrezok))

# %%
position = 11

df=data_list[position][0]
df.columns=["X","Y","Z"]

fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)

fig = plt.figure(1, figsize=(10,10))
ax = fig.gca(projection='3d')
 
 # Give points 
x = [data_list[position][1][0], data_list[position][1][1]]
y = [data_list[position][1][2], data_list[position][1][3]]
z = np.array([data_list[position][1][4], data_list[position][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array
figure = ax.plot(x, y, z, c='r', )
plt.show()
print(data_list[position][1])
# Out:
#             0          1          2          3         4         5         6
# 11  37.342238  32.505919  23.413523  29.373924 -2.374276 -7.081008  3.308346

# %%
from sklearn.preprocessing import normalize #machine learning algorithm library
from sklearn.preprocessing import MaxAbsScaler

# %%
X = np.array(data)[:,2]
X = np.reshape(X,(-1,1600))
print("Examples of X\n",X[:1])

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
print("Examples of X_scaled\n",X_scaled[:1])

Y = np.array(otrezok)

print("Shape of Y",Y.shape)
print("Examples of Y\n",Y[:1])

y_scaler = MinMaxScaler()
Y_scaled = y_scaler.fit_transform(Y)
print("Examples of Y_scaled\n",Y_scaled[:1])

# X_normalized=normalize(X, norm='l2')
# print("Examples of X normalized \n",X_normalized[:1])

# Y = np.array(otrezok)
# print("Examples of Y\n",Y[:1])

# Y_normalized=normalize(Y, norm='l2')
# print("Examples of Y normalized\n",Y[:1])
# Out:
# Examples of X
#  [[-0.00143977 -0.00154781 -0.00166551 ... -0.00621236 -0.00583679
#   -0.00546311]]
# Examples of X_scaled
#  [[0.99542948 0.99664882 0.99719871 ... 0.99347947 0.99219716 0.98911929]]
# Shape of Y (301, 7)
# Examples of Y
#  [[14.5648281  23.43296079 27.3509389  28.8206247  -1.87248872 -5.34937917
#    2.45072687]]
# Examples of Y_scaled
#  [[0.36428799 0.5551056  0.68344986 0.68695193 0.3889459  0.37531623
#   0.6121703 ]]

# %%
total_length=len(X)
train_length=int(0.8*total_length)
test_length=int(0.2*total_length)
# print(train_length)
# print(test_length)

X_train=X_scaled[:train_length]
X_test=X_scaled[train_length:]
y_train=Y_scaled[:train_length]
y_test=Y_scaled[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])
# Out:
# Length of train set x: 240 y: 240
# Length of test set x: 61 y: 61

# %%
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout,LSTM,Embedding 
from keras.layers.normalization import BatchNormalization 
from keras.utils import np_utils

# %%
model = Sequential()
model.add(Dense(3000,input_dim=1600,activation='relu'))
model.add(Dense(1500,activation='relu'))
model.add(Dense(700,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(7,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

#model.add(Dense(1000,input_dim=1600,activation='tanh'))
# model.add(Embedding(input_dim=1600, output_dim=64))
# model.add(LSTM(128))
# model.add(Dense(700,activation='tanh'))
# model.add(Dropout(0.3))
# model.add(Dense(7,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3000)              4803000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1500)              4501500
# _________________________________________________________________
# dense_2 (Dense)              (None, 700)               1050700
# _________________________________________________________________
# dropout (Dropout)            (None, 700)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 4907
# =================================================================
# Total params: 10,360,107
# Trainable params: 10,360,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=25,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 2s 138ms/step - loss: 1.6647 - accuracy: 0.1595 - val_loss: 0.7206 - val_accuracy: 0.2131
# Epoch 2/50
# 10/10 [==============================] - 1s 112ms/step - loss: 0.7421 - accuracy: 0.1827 - val_loss: 0.7015 - val_accuracy: 0.1803
# Epoch 3/50
# 10/10 [==============================] - 1s 111ms/step - loss: 0.7004 - accuracy: 0.1444 - val_loss: 0.6986 - val_accuracy: 0.1803
# Epoch 4/50
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6912 - accuracy: 0.1693 - val_loss: 0.6939 - val_accuracy: 0.2459
# Epoch 5/50
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6900 - accuracy: 0.2132 - val_loss: 0.6938 - val_accuracy: 0.2131
# Epoch 6/50
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6912 - accuracy: 0.2055 - val_loss: 0.6939 - val_accuracy: 0.2131
# Epoch 7/50
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6917 - accuracy: 0.2204 - val_loss: 0.6934 - val_accuracy: 0.2131
# Epoch 8/50
# 10/10 [==============================] - 1s 116ms/step - loss: 0.6904 - accuracy: 0.1805 - val_loss: 0.6935 - val_accuracy: 0.2131
# Epoch 9/50
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6906 - accuracy: 0.2376 - val_loss: 0.6938 - val_accuracy: 0.2459
# Epoch 10/50
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6896 - accuracy: 0.1925 - val_loss: 0.6919 - val_accuracy: 0.2131
# Epoch 11/50
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6888 - accuracy: 0.2001 - val_loss: 0.6917 - val_accuracy: 0.2951
# Epoch 12/50
# 10/10 [==============================] - 1s 114ms/step - loss: 0.6876 - accuracy: 0.2467 - val_loss: 0.6908 - val_accuracy: 0.2131
# Epoch 13/50
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6874 - accuracy: 0.2555 - val_loss: 0.6929 - val_accuracy: 0.2295
# Epoch 14/50
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6858 - accuracy: 0.2117 - val_loss: 0.6910 - val_accuracy: 0.1803
# Epoch 15/50
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6885 - accuracy: 0.2258 - val_loss: 0.6892 - val_accuracy: 0.2131
# Epoch 16/50
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6807 - accuracy: 0.2586 - val_loss: 0.6778 - val_accuracy: 0.2295
# Epoch 17/50
# 10/10 [==============================] - 1s 113ms/step - loss: 0.6750 - accuracy: 0.2361 - val_loss: 0.6925 - val_accuracy: 0.2295
# Epoch 18/50
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6824 - accuracy: 0.2857 - val_loss: 0.6651 - val_accuracy: 0.2787
# Epoch 19/50
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6624 - accuracy: 0.2775 - val_loss: 0.6506 - val_accuracy: 0.3934
# Epoch 20/50
# 10/10 [==============================] - 1s 112ms/step - loss: 0.6530 - accuracy: 0.2972 - val_loss: 0.6703 - val_accuracy: 0.2951
# Epoch 21/50
# 10/10 [==============================] - 1s 110ms/step - loss: 0.6645 - accuracy: 0.2245 - val_loss: 0.6687 - val_accuracy: 0.2787
# Epoch 22/50
# 10/10 [==============================] - 1s 110ms/step - loss: 0.
# 10/10 [==============================] - 1s 111ms/step - loss: 0.6002 - accuracy: 0.5156 - val_loss: 0.6159 - val_accuracy: 0.4754

# %%
prediction=model.predict(X_test)
length=len(prediction)
y_label=np.argmax(y_test,axis=1)
predict_label=np.argmax(prediction,axis=1)

accuracy=np.sum(y_label==predict_label)/length * 100 
print("Accuracy of the dataset",accuracy )
# Out:
# Accuracy of the dataset 47.540983606557376

# %%
result = y_scaler.inverse_transform(prediction)

# %%
fig2 = plt.figure(1, figsize=(10,10))
ax2 = fig2.gca(projection='3d')

pos = 21
 # Give points 
x1 = [data_list[240 + pos][1][0], data_list[240 + pos][1][1]]
y1 = [data_list[240 + pos][1][2], data_list[240 + pos][1][3]]
z1 = np.array([data_list[240 + pos][1][4], data_list[240 + pos][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array

ax3 = fig2.gca(projection='3d')

 # Give points 
x2 = [result[pos][0], result[pos][1]]
y2 = [result[pos][2], result[pos][3]]
z2 = np.array([result[pos][4], result[pos][5]]).flatten()

figure = ax2.plot(x1, y1, z1, c='r', )
figure = ax3.plot(x2, y2, z2, c='b', )
plt.show()

print("weight: ", data_list[pos][1][6])
print("weight predicted: ", result[pos][6])
# Out:
# weight:  21    0.761507
# Name: 6, dtype: float64
# weight predicted:  1.0126942

# %%
X_input = np.reshape(X_scaled,(-1, 40, 40)) #np.reshape(X, X.shape + (1,))
# print(X_input.shape)
# print(X_input[:1])
Y_output1 = np.array(Y_scaled)[0:,0:6]
Y_output2 = np.array(Y_scaled)[0:,6:7]

X_train2=X_input[:train_length]
X_test2=X_input[train_length:]
y_train21=Y_output1[:train_length]
y_test21=Y_output1[train_length:]
y_train22=Y_output2[:train_length]
y_test22=Y_output2[train_length:]

# %%
# losses = {'weight': 'binary_crossentropy',
#           'coordinates': 'mse'}
losses = {'weight': 'mae',
          'coordinates': 'binary_crossentropy'}
loss_weights = {'weight': 1.0,
                'coordinates': 1.0}

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D

# %%
from keras.models import Model

# %%
def get_model():
    inputs = Input(shape=(40,40,1))
    x = Conv2D(32, (3,3), activation='relu')(inputs)
    x = MaxPooling2D((3,3))(x)
    x = Conv2D(32, (3,3), activation='relu')(x)
    x = MaxPooling2D((3,3))(x)
    x = Conv2D(64, (3,3), activation='relu')(x)
    x = GlobalAveragePooling2D()(x)
    classifier_head = Dropout(0.3)(x)
    # Notice the name of the layer.
    classifier_head = Dense(1, activation='sigmoid', name='weight')(classifier_head)
    reg_head = Dense(64, activation='relu')(x)
    reg_head = Dense(32, activation='relu')(reg_head)
    # Notice the name of the layer.
    reg_head = Dense(6, activation='sigmoid', name='coordinates')(reg_head)
    return Model(inputs=[inputs], outputs=[classifier_head, reg_head])

# %%
x_model = get_model()
x_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 40, 40, 1)]  0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 38, 38, 32)   320         input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 32)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 10, 10, 32)   9248        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 32)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 1, 1, 64)     18496       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 64)           0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           4160        global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 32)           2080        dense_10[0][0]
# __________________________________________________________________________________________________
# weight (Dense)                  (None, 1)            65          dropout_4[0][0]
# __________________________________________________________________________________________________
# coordinates (Dense)             (None, 6)            198         dense_11[0][0]
# ==================================================================================================
# Total params: 34,567
# Trainable params: 34,567
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
x
50
# 10/10 [==============================] - 0s 37ms/step - loss: 0.5888 - weight_loss: 0.0509 - coordinates_loss: 0.5379 - weight_acc: 0.0028 - coordinates_acc: 0.7250 - val_loss: 0.6923 - val_weight_loss: 0.0984 - val_coordinates_loss: 0.5938 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3934
# Epoch 43/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.5917 - weight_loss: 0.0488 - coordinates_loss: 0.5429 - weight_acc: 0.0221 - coordinates_acc: 0.6860 - val_loss: 0.7106 - val_weight_loss: 0.1075 - val_coordinates_loss: 0.6031 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3934
# Epoch 44/50
# 10/10 [==============================] - 0s 37ms/step - loss: 0.6064 - weight_loss: 0.0615 - coordinates_loss: 0.5449 - weight_acc: 0.0127 - coordinates_acc: 0.7213 - val_loss: 0.7000 - val_weight_loss: 0.1003 - val_coordinates_loss: 0.5997 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3770
# Epoch 45/50
# 10/10 [==============================] - 0s 38ms/step - loss: 0.5937 - weight_loss: 0.0468 - coordinates_loss: 0.5469 - weight_acc: 0.0130 - coordinates_acc: 0.6875 - val_loss: 0.6896 - val_weight_loss: 0.0974 - val_coordinates_loss: 0.5921 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.4262
# Epoch 46/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.5961 - weight_loss: 0.0518 - coordinates_loss: 0.5443 - weight_acc: 0.0063 - coordinates_acc: 0.6865 - val_loss: 0.6997 - val_weight_loss: 0.1037 - val_coordinates_loss: 0.5960 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3934
# Epoch 47/50
# 10/10 [==============================] - 0s 38ms/step - loss: 0.5982 - weight_loss: 0.0547 - coordinates_loss: 0.5435 - weight_acc: 0.0019 - coordinates_acc: 0.6746 - val_loss: 0.6941 - val_weight_loss: 0.0990 - val_coordinates_loss: 0.5951 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3770
# Epoch 48/50
# 10/10 [==============================] - 0s 38ms/step - loss: 0.5865 - weight_loss: 0.0497 - coordinates_loss: 0.5369 - weight_acc: 0.0071 - coordinates_acc: 0.6914 - val_loss: 0.6908 - val_weight_loss: 0.0986 - val_coordinates_loss: 0.5922 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3934
# Epoch 49/50
# 10/10 [==============================] - 0s 38ms/step - loss: 0.5892 - weight_loss: 0.0470 - coordinates_loss: 0.5421 - weight_acc: 0.0145 - coordinates_acc: 0.6699 - val_loss: 0.6886 - val_weight_loss: 0.0945 - val_coordinates_loss: 0.5941 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3770
# Epoch 50/50
# 10/10 [==============================] - 0s 36ms/step - loss: 0.5964 - weight_loss: 0.0571 - coordinates_loss: 0.5393 - weight_acc: 0.0166 - coordinates_acc: 0.7168 - val_loss: 0.6825 - val_weight_loss: 0.0913 - val_coordinates_loss: 0.5912 - val_weight_acc: 0.0000e+00 - val_coordinates_acc: 0.3934

# %%
result_2=x_model.predict(X_test2)
res = np.column_stack(result_2)
result_2_inv = y_scaler.inverse_transform(res)
#print(result_2_inv)

# %%
fig2 = plt.figure(1, figsize=(10,10))
ax2 = fig2.gca(projection='3d')

pos = 3
 # Give points 
x1 = [data_list[240 + pos][1][0], data_list[240 + pos][1][1]]
y1 = [data_list[240 + pos][1][2], data_list[240 + pos][1][3]]
z1 = np.array([data_list[240 + pos][1][4], data_list[240 + pos][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array

ax3 = fig2.gca(projection='3d')

 # Give points 
x2 = [result_2_inv[pos][0], result_2_inv[pos][1]]
y2 = [result_2_inv[pos][2], result_2_inv[pos][3]]
z2 = np.array([result_2_inv[pos][4], result_2_inv[pos][5]]).flatten()

figure = ax2.plot(x1, y1, z1, c='r', )
figure = ax3.plot(x2, y2, z2, c='b', )
plt.show()

print("weight: ", data_list[pos][1][6])
print("weight predicted: ", result_2_inv[pos][6])
# Out:
# weight:  3    2.211242
# Name: 6, dtype: float64
# weight predicted:  2.484719
