# %% [markdown]
# <a href="https://colab.research.google.com/github/AnosovAndrey/Task/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library
from sklearn.preprocessing import MinMaxScaler
from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv("../content/input/data.csv", header=None)
otrezok=pd.read_csv("../content/input/otrezok.csv", header=None)
print("Info of the data:",data.info())
print("Info of the data:",otrezok.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81600 entries, 0 to 81599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       81600 non-null  int64
#  1   1       81600 non-null  int64
#  2   2       81600 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.9 MB
# Info of the data: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       51 non-null     float64
#  1   1       51 non-null     float64
#  2   2       51 non-null     float64
#  3   3       51 non-null     float64
#  4   4       51 non-null     float64
#  5   5       51 non-null     float64
#  6   6       51 non-null     float64
# dtypes: float64(7)
# memory usage: 2.9 KB
# Info of the data: None

# %%
print("10 first samples of the dataset:",data.head(10))
# Out:
# 10 first samples of the dataset:    0  1         2
# 0  0  0 -0.000133
# 1  0  1 -0.000142
# 2  0  2 -0.000152
# 3  0  3 -0.000163
# 4  0  4 -0.000174
# 5  0  5 -0.000186
# 6  0  6 -0.000199
# 7  0  7 -0.000213
# 8  0  8 -0.000228
# 9  0  9 -0.000244

# %%
print("10 first samples of the dataset:",otrezok.head(10))
# Out:
# 10 first samples of the dataset:            0          1          2          3         4         5         6
# 0  18.910609  24.636987  23.804058  32.531139 -0.299126 -2.523170  0.693177
# 1  27.457650  33.285403   1.606574   5.985465 -1.200618 -4.745960  3.104107
# 2  32.331055  22.696392  33.646802  25.464937 -1.276281 -5.962238  2.624864
# 3  29.017940  31.459544  13.336898  17.503629 -0.434797 -4.033270  2.680604
# 4  24.081365  27.282964  21.721828  24.718316 -0.999756 -2.273734  3.628786
# 5  33.010155  35.979406  27.808975  29.411654 -0.227572 -1.780491  1.968672
# 6  34.168841  27.525834  20.954206  28.912733 -0.691230 -3.437299  1.015973
# 7  29.399985  38.040064  34.062080  36.700082 -0.495209 -2.743836  3.353466
# 8   2.213558   8.107325   2.690309  11.017855 -1.394131 -5.455259  1.481441
# 9  26.768828  32.677907  25.787782  33.766821 -1.298380 -2.665307  2.918528

# %%
print(len(data))
splited_data = np.array_split(data, 51)
splited_otrezok = np.array_split(otrezok, 51)
data_list = list(zip(splited_data, splited_otrezok))
print(data_list[0][1])
# Out:
# 81600
#            0          1          2          3         4        5         6
# 0  18.910609  24.636987  23.804058  32.531139 -0.299126 -2.52317  0.693177

# %%
z = np.array([data_list[0][1][4], data_list[0][1][5]])
print(len(z))
print(z[0])
# Out:
# 2
# [-0.29912582]

# %%
position = 15

df=data_list[position][0]
df.columns=["X","Y","Z"]

fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(10,10))
ax = fig.gca(projection='3d')
 
 # Give points 
x = [data_list[position][1][0], data_list[position][1][1]]
y = [data_list[position][1][2], data_list[position][1][3]]
z = np.array([data_list[position][1][4], data_list[position][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array
figure = ax.plot(x, y, z, c='r', )
plt.show()

print("weight: ", data_list[position][1][6])
# Out:
# weight:  15    3.285688
# Name: 6, dtype: float64

# %%
#Normalization

X = np.array(data)[:,2]
X = np.reshape(X,(-1,1600))

print("Shape of X",X.shape)
print("Examples of X\n",X[:3])

X_normalized = normalize(X, axis=0)
print("Examples of X_normalised\n",X_normalized[:3])
# Out:
# Shape of X (51, 1600)
# Examples of X
#  [[-0.00013326 -0.00014234 -0.00015212 ... -0.00115107 -0.0010742
#   -0.00099639]
#  [-0.00202335 -0.00204491 -0.00206033 ... -0.00159117 -0.00146171
#   -0.00134574]
#  [-0.00108728 -0.00115145 -0.00121952 ... -0.02545546 -0.02226415
#   -0.01933642]]
# Examples of X_normalised
#  [[-0.00127441 -0.00094898 -0.00074382 ... -0.00198043 -0.00235996
#   -0.00308752]
#  [-0.01935017 -0.01363343 -0.0100743  ... -0.00273764 -0.00321132
#   -0.00417007]
#  [-0.01039813 -0.00767675 -0.00596305 ... -0.04379658 -0.04891338
#   -0.05991798]]
