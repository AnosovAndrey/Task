# %% [markdown]
# <a href="https://colab.research.google.com/github/AnosovAndrey/Task/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import required libraries 
import keras #library for neural network
import pandas as pd #loading data in table form  
import seaborn as sns #visualisation 
import matplotlib.pyplot as plt #visualisation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import normalize #machine learning algorithm library
from sklearn.preprocessing import MinMaxScaler
from mpl_toolkits.mplot3d import Axes3D

# %%
data=pd.read_csv("../content/input/data.csv", header=None)
otrezok=pd.read_csv("../content/input/otrezok.csv", header=None)
print("Info of the data:",data.info())
print("Info of the data:",otrezok.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481600 entries, 0 to 481599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       481600 non-null  int64
#  1   1       481600 non-null  int64
#  2   2       481600 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 11.0 MB
# Info of the data: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       301 non-null    float64
#  1   1       301 non-null    float64
#  2   2       301 non-null    float64
#  3   3       301 non-null    float64
#  4   4       301 non-null    float64
#  5   5       301 non-null    float64
#  6   6       301 non-null    float64
# dtypes: float64(7)
# memory usage: 16.6 KB
# Info of the data: None

# %%
print("10 first samples of the dataset:",data.head(3))
# Out:
# 10 first samples of the dataset:    0  1         2
# 0  0  0 -0.001440
# 1  0  1 -0.001548
# 2  0  2 -0.001666

# %%
print("10 first samples of the dataset:",otrezok.head(3))
# Out:
# 10 first samples of the dataset:            0          1          2          3         4         5         6
# 0  14.564828  23.432961  27.350939  28.820625 -1.872489 -5.349379  2.450727
# 1  35.009724  29.750053  30.112231  36.582260 -1.138215 -3.501332  0.315040
# 2  24.324980  25.896508  21.878457  29.620625 -1.012698 -2.743962  2.842393

# %%
print(len(data))
splited_data = np.array_split(data, 301)
splited_otrezok = np.array_split(otrezok, 301)
data_list = list(zip(splited_data, splited_otrezok))
print(data_list[0][1])
# Out:
# 481600
#            0          1          2          3         4         5         6
# 0  14.564828  23.432961  27.350939  28.820625 -1.872489 -5.349379  2.450727

# %%
position = 1

df=data_list[position][0]
df.columns=["X","Y","Z"]

fig = plt.figure(figsize=(10,10))
ax = fig.gca(projection='3d')
ax.plot_trisurf(df['Y'], df['X'], df['Z'], cmap=plt.cm.viridis, linewidth=0.2)
plt.show()

# %%
fig = plt.figure(1, figsize=(10,10))
ax = fig.gca(projection='3d')
 
 # Give points 
x = [data_list[position][1][0], data_list[position][1][1]]
y = [data_list[position][1][2], data_list[position][1][3]]
z = np.array([data_list[position][1][4], data_list[position][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array
figure = ax.plot(x, y, z, c='r', )
plt.show()

print("weight: ", data_list[position][1][6])
# Out:
# weight:  1    0.31504
# Name: 6, dtype: float64

# %%
#Normalisation module

X = np.array(data)[:,2]
X = np.reshape(X,(-1,1600))

print("Shape of X",X.shape)
print("Examples of X\n",X[:1])

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
print("Examples of X_scaled\n",X_scaled[:1])

# X_normalized = normalize(X, axis=0)
# print("Examples of X_normalised\n",X_normalized[:3])

#inverse norm
# X_inv = scaler.inverse_transform(X_scaled)
# print("Examples of X_inv\n",X_inv[:3])

#### 7 on output
Y = np.array(otrezok)

print("Shape of Y",Y.shape)
print("Examples of Y\n",Y[:1])

y_scaler = MinMaxScaler()
Y_scaled = y_scaler.fit_transform(Y)
print("Examples of Y_scaled\n",Y_scaled[:1])


# Y_inv = y_scaler.inverse_transform(Y_scaled)
# print("Examples of Y_inv\n",Y_inv[:3])
# Out:
# Shape of X (301, 1600)
# Examples of X
#  [[-0.00143977 -0.00154781 -0.00166551 ... -0.00621236 -0.00583679
#   -0.00546311]]
# Examples of X_scaled
#  [[0.99542948 0.99664882 0.99719871 ... 0.99347947 0.99219716 0.98911929]]
# Shape of Y (301, 7)
# Examples of Y
#  [[14.5648281  23.43296079 27.3509389  28.8206247  -1.87248872 -5.34937917
#    2.45072687]]
# Examples of Y_scaled
#  [[0.36428799 0.5551056  0.68344986 0.68695193 0.3889459  0.37531623
#   0.6121703 ]]

# %%
total_length=len(X)
train_length=int(0.8*total_length)
test_length=int(0.2*total_length)
# print(train_length)
# print(test_length)

X_train=X_scaled[:train_length]
X_test=X_scaled[train_length:]
y_train=Y_scaled[:train_length]
y_test=Y_scaled[train_length:]

print("Length of train set x:",X_train.shape[0],"y:",y_train.shape[0])
print("Length of test set x:",X_test.shape[0],"y:",y_test.shape[0])

#print("Shape of y_train",X_train.shape)
# Out:
# Length of train set x: 240 y: 240
# Length of test set x: 61 y: 61

# %%
#Neural network module
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
from keras.layers.normalization import BatchNormalization 
from keras.utils import np_utils

# %%
model=Sequential()

# model.add(Dense(1600,input_dim=1600,activation='relu'))
# model.add(Dense(2000,activation='relu'))
# model.add(Dense(2000,activation='relu'))
# model.add(Dense(2000,activation='relu'))
# #model.add(Dense(300,activation='relu'))
# model.add(Dropout(0.3))
# model.add(Dense(7,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])


#### 0.5
# model.add(Dense(2000,input_dim=1600,activation='sigmoid')) 
# model.add(Dense(2500,activation='sigmoid'))
# model.add(Dense(300,activation='sigmoid'))
# model.add(Dropout(0.3))
# model.add(Dense(7,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

##### 0.57
model.add(Dense(3000,input_dim=1600,activation='relu'))
model.add(Dense(1500,activation='relu'))
model.add(Dense(700,activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(7,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

######### 0.52
# model.add(Dense(3200,input_dim=1600,activation='relu'))
# model.add(Dense(1600,activation='relu'))
# model.add(Dense(700,activation='relu'))
# model.add(Dropout(0.3))
# model.add(Dense(7,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# model.add(Dense(1000,input_dim=1600,activation='sigmoid'))
# model.add(Dense(800,activation='sigmoid'))
# model.add(Dense(600,activation='sigmoid'))
# model.add(Dropout(0.3))
# model.add(Dense(7,activation='sigmoid'))
# model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
#model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy']) ### 0.4


#model.compile(loss='mse',optimizer='adam',metrics=['accuracy'])
# model.compile(
#     optimizer=keras.optimizers.RMSprop(1e-3),
#     loss=['binary_crossentropy'], metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 3000)              4803000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1500)              4501500
# _________________________________________________________________
# dense_2 (Dense)              (None, 700)               1050700
# _________________________________________________________________
# dropout (Dropout)            (None, 700)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 4907
# ...
# Total params: 10,360,107
# Trainable params: 10,360,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),batch_size=25,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 2s 139ms/step - loss: 1.5466 - accuracy: 0.1314 - val_loss: 0.7656 - val_accuracy: 0.2131
# Epoch 2/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.7455 - accuracy: 0.2080 - val_loss: 0.7048 - val_accuracy: 0.2131
# Epoch 3/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.6958 - accuracy: 0.1381 - val_loss: 0.6955 - val_accuracy: 0.2131
# Epoch 4/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.6921 - accuracy: 0.2166 - val_loss: 0.6948 - val_accuracy: 0.1803
# Epoch 5/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.6950 - accuracy: 0.1764 - val_loss: 0.6941 - val_accuracy: 0.2131
# Epoch 6/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.6883 - accuracy: 0.1877 - val_loss: 0.6919 - val_accuracy: 0.2131
# Epoch 7/100
# ...

# %%
prediction=model.predict(X_test)
length=len(prediction)
y_label=np.argmax(y_test,axis=1)
predict_label=np.argmax(prediction,axis=1)

accuracy=np.sum(y_label==predict_label)/length * 100 
print("Accuracy of the dataset",accuracy )
# Out:
# Accuracy of the dataset 55.73770491803278

# %%
index_is_test = 25
result=model.predict(X_test)
print(result[index_is_test])
print(Y[240 + index_is_test ])

Y_inv = y_scaler.inverse_transform([result[index_is_test]])
print("Examples of Y_inv\n",Y_inv[:1])
# Y_full_inv = y_scaler.inverse_transform(result)
# print("full result \n", Y_full_inv)
# Out:
# [0.17232543 0.25950825 0.68104625 0.7312727  0.5656072  0.46815115
#  0.17148003]
# [ 8.89397427 12.4286103  25.47383847 32.37077781 -2.85941316 -7.14834104
#   1.29246822]
# Examples of Y_inv
#  [[ 6.93809583 12.45955081 27.25663802 30.40048719 -1.36276884 -4.75315829
#    0.690528  ]]

# %%
######### split data
weight = np.array(otrezok)[0:,6:7]
print("Shape of weight",weight.shape)
print("Examples of weight\n",weight[:1])
weight_scaler = MinMaxScaler()
weight_scaled = weight_scaler.fit_transform(weight)
print("Examples of weight_scaled\n",weight_scaled[:4])
# Out:
# Shape of weight (301, 1)
# Examples of weight
#  [[2.45072687]]
# Examples of weight_scaled
#  [[0.6121703 ]
#  [0.07747144]
#  [0.7102294 ]
#  [0.552212  ]]

# %%
weight_train=weight_scaled[:train_length]
weight_test=weight_scaled[train_length:]

print("Length of train set weight:",weight_train.shape[0], "weight:",weight_train.shape)
# Out:
# Length of train set weight: 240 weight: (240, 1)

# %%
weight_model=Sequential()

# #### 
weight_model.add(Dense(3200,input_dim=1600,activation='relu'))
weight_model.add(Dense(1000,activation='relu'))
# weight_model.add(Dense(100,activation='sigmoid'))
#weight_model.add(Dropout(0.3))
weight_model.add(Dense(1,activation='sigmoid'))
#weight_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
weight_model.compile(
              #optimizer='rmsprop',
              optimizer='adam',
              loss='binary_crossentropy',
              #loss='mse',
              metrics='mean_absolute_error')
              #metrics=['accuracy'])

# weight_model.add(Dense(3000,input_dim=1600,activation='sigmoid'))
# weight_model.add(Dense(1500,activation='sigmoid'))
# weight_model.add(Dense(600,activation='sigmoid'))
# weight_model.add(Dropout(0.3))
# weight_model.add(Dense(1,activation='sigmoid'))
# weight_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['mean_absolute_error'])

# %%
weight_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 3200)              5123200
# _________________________________________________________________
# dense_5 (Dense)              (None, 1000)              3201000
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 1001
# ...
# Total params: 8,325,201
# Trainable params: 8,325,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
weight_model.fit(X_train,weight_train,validation_data=(X_test,weight_test),batch_size=25,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 82ms/step - loss: 6.3092 - mean_absolute_error: 0.4145 - val_loss: 1.1670 - val_mean_absolute_error: 0.3908
# Epoch 2/50
# 10/10 [==============================] - 1s 68ms/step - loss: 1.0465 - mean_absolute_error: 0.3578 - val_loss: 0.7212 - val_mean_absolute_error: 0.2301
# Epoch 3/50
# 10/10 [==============================] - 1s 67ms/step - loss: 0.7250 - mean_absolute_error: 0.2463 - val_loss: 0.6926 - val_mean_absolute_error: 0.2194
# Epoch 4/50
# 10/10 [==============================] - 1s 65ms/step - loss: 0.6970 - mean_absolute_error: 0.2456 - val_loss: 0.7022 - val_mean_absolute_error: 0.2301
# Epoch 5/50
# 10/10 [==============================] - 1s 67ms/step - loss: 0.7022 - mean_absolute_error: 0.2460 - val_loss: 0.6938 - val_mean_absolute_error: 0.2210
# Epoch 6/50
# ...

# %%
index_2 = 5
weight_result=weight_model.predict(X_test)
print("result: ", weight_result[index_2])
print("scaled: ", weight_test[index_2])
print("unscaled: ", weight[240 + index_2])

weight_inv = weight_scaler.inverse_transform([weight_result[index_2]])
print("result unscaled: ", weight_inv[:1])
# Out:
# result:  [0.45302266]
# scaled:  [0.37210924]
# unscaled:  [1.49187835]
# result unscaled:  [[1.81506159]]

# %%
###### split coordinates
coordinates = np.array(otrezok)[0:,0:2]
print("Shape of coordinates",coordinates.shape)
print("Examples of coordinates\n",coordinates[:1])
coordinates_scaler = MinMaxScaler()
coordinates_scaled =coordinates_scaler.fit_transform(coordinates)
print("Examples of coordinates_scaled\n",coordinates_scaled[:1])
# Out:
# Shape of coordinates (301, 2)
# Examples of coordinates
#  [[14.5648281  23.43296079]]
# Examples of coordinates_scaled
#  [[0.36428799 0.5551056 ]]

# %%
coordinates_train=coordinates_scaled[:train_length]
coordinates_test=coordinates_scaled[train_length:]

print("Length of train set coordinates:",coordinates_test.shape, "coordinates:",coordinates_train.shape)
# Out:
# Length of train set coordinates: (61, 2) coordinates: (240, 2)

# %%
coordinates_model=Sequential()

##### 0.77
# coordinates_model.add(Dense(3000,input_dim=1600,activation='relu'))
# coordinates_model.add(Dense(1500,activation='relu'))
# coordinates_model.add(Dense(600,activation='relu'))
# coordinates_model.add(Dropout(0.3))
# coordinates_model.add(Dense(2,activation='sigmoid'))
# coordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

coordinates_model.add(Dense(1600,input_dim=1600,activation='relu'))
coordinates_model.add(Dense(600,activation='relu'))
coordinates_model.add(Dense(200,activation='relu'))
coordinates_model.add(Dropout(0.3))
coordinates_model.add(Dense(2,activation='sigmoid'))
coordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['categorical_accuracy'])

# %%
coordinates_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 1600)              2561600
# _________________________________________________________________
# dense_8 (Dense)              (None, 600)               960600
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               120200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 402
# ...
# Total params: 3,642,802
# Trainable params: 3,642,802
# Non-trainable params: 0
# _________________________________________________________________

# %%
coordinates_model.fit(X_train,coordinates_train,validation_data=(X_test,coordinates_test),batch_size=25,epochs=30,verbose=1)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 1s 50ms/step - loss: 1.4151 - categorical_accuracy: 0.6636 - val_loss: 0.7982 - val_categorical_accuracy: 0.7705
# Epoch 2/30
# 10/10 [==============================] - 0s 33ms/step - loss: 0.7942 - categorical_accuracy: 0.5589 - val_loss: 0.7222 - val_categorical_accuracy: 0.2295
# Epoch 3/30
# 10/10 [==============================] - 0s 35ms/step - loss: 0.7196 - categorical_accuracy: 0.4713 - val_loss: 0.7568 - val_categorical_accuracy: 0.7705
# Epoch 4/30
# 10/10 [==============================] - 0s 33ms/step - loss: 0.7107 - categorical_accuracy: 0.5205 - val_loss: 0.6923 - val_categorical_accuracy: 0.7705
# Epoch 5/30
# 10/10 [==============================] - 0s 35ms/step - loss: 0.6866 - categorical_accuracy: 0.7555 - val_loss: 0.6938 - val_categorical_accuracy: 0.7705
# Epoch 6/30
# ...

# %%
index_in_coord = 4
coordinates_result=coordinates_model.predict(X_test)
print(coordinates_result[index_in_coord])
print(coordinates[240 + index_in_coord])

coordinates_inv = coordinates_scaler.inverse_transform([coordinates_result[index_in_coord]])
print("Examples of coordinates_inv\n",coordinates_inv[:1])
# Out:
# [0.58909774 0.63866115]
# [16.26733986 24.77577415]
# Examples of coordinates_inv
#  [[23.49658948 26.53477919]]

# %%
###### split y coordinates
Ycoordinates = np.array(otrezok)[0:,2:4]
print("Shape of Ycoordinates",Ycoordinates.shape)
print("Examples of Ycoordinates\n",Ycoordinates[:1])
Ycoordinates_scaler = MinMaxScaler()
Ycoordinates_scaled =Ycoordinates_scaler.fit_transform(Ycoordinates)
print("Examples of Ycoordinates_scaled\n",Ycoordinates_scaled[:1])
# Out:
# Shape of Ycoordinates (301, 2)
# Examples of Ycoordinates
#  [[27.3509389 28.8206247]]
# Examples of Ycoordinates_scaled
#  [[0.68344986 0.68695193]]

# %%
Ycoordinates_train=Ycoordinates_scaled[:train_length]
Ycoordinates_test=Ycoordinates_scaled[train_length:]

print("Length of train set Ycoordinates:",Ycoordinates_test.shape, "Ycoordinates:",Ycoordinates_train.shape)
# Out:
# Length of train set Ycoordinates: (61, 2) Ycoordinates: (240, 2)

# %%
Ycoordinates_model=Sequential()

##### 0.77
# coordinates_model.add(Dense(3000,input_dim=1600,activation='relu'))
# coordinates_model.add(Dense(1500,activation='relu'))
# coordinates_model.add(Dense(600,activation='relu'))
# coordinates_model.add(Dropout(0.3))
# coordinates_model.add(Dense(2,activation='sigmoid'))
# coordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

Ycoordinates_model.add(Dense(3000,input_dim=1600,activation='relu'))
Ycoordinates_model.add(Dense(1500,activation='relu'))
Ycoordinates_model.add(Dense(600,activation='relu'))
Ycoordinates_model.add(Dropout(0.3))
Ycoordinates_model.add(Dense(2,activation='sigmoid'))
Ycoordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
Ycoordinates_model.fit(X_train,Ycoordinates_train,validation_data=(X_test,Ycoordinates_test),batch_size=30,epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 112ms/step - loss: 2.9201 - accuracy: 0.4200 - val_loss: 0.7412 - val_accuracy: 0.2951
# Epoch 2/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.8598 - accuracy: 0.4206 - val_loss: 0.7458 - val_accuracy: 0.2951
# Epoch 3/50
# 8/8 [==============================] - 1s 91ms/step - loss: 0.7489 - accuracy: 0.4565 - val_loss: 0.7073 - val_accuracy: 0.2951
# Epoch 4/50
# 8/8 [==============================] - 1s 86ms/step - loss: 0.7006 - accuracy: 0.5094 - val_loss: 0.6930 - val_accuracy: 0.7049
# Epoch 5/50
# 8/8 [==============================] - 1s 88ms/step - loss: 0.6914 - accuracy: 0.6613 - val_loss: 0.6975 - val_accuracy: 0.7049
# Epoch 6/50
# 8/8 [==============================] - 1s 90ms/step - loss: 0.7016 - accuracy: 0.6585 - val_loss: 0.6937 - val_accuracy: 0.7049
# Epoch 7/50
# ...

# %%
index_in_Ycoord = 4
Ycoordinates_result=Ycoordinates_model.predict(X_test)
print(Ycoordinates_result[index_in_coord])
print(Ycoordinates[240 + index_in_coord])

Ycoordinates_inv = Ycoordinates_scaler.inverse_transform([Ycoordinates_result[index_in_Ycoord]])
print("Examples of coordinates_inv\n",Ycoordinates_inv[:1])
# Out:
# [0.7354283 0.776103 ]
# [26.48686031 29.42969506]
# Examples of coordinates_inv
#  [[29.39020749 31.99851315]]

# %%
###### split z coordinates
Zcoordinates = np.array(otrezok)[0:,4:6]
print("Shape of Zcoordinates",Zcoordinates.shape)
print("Examples of Zcoordinates\n",Zcoordinates[:1])
Zcoordinates_scaler = MinMaxScaler()
Zcoordinates_scaled =Zcoordinates_scaler.fit_transform(Zcoordinates)
print("Examples of Zcoordinates_scaled\n",Zcoordinates_scaled[:1])
# Out:
# Shape of Zcoordinates (301, 2)
# Examples of Zcoordinates
#  [[-1.87248872 -5.34937917]]
# Examples of Zcoordinates_scaled
#  [[0.3889459  0.37531623]]

# %%
Zcoordinates_train=Zcoordinates_scaled[:train_length]
Zcoordinates_test=Zcoordinates_scaled[train_length:]

print("Length of train set Ycoordinates:",Ycoordinates_test.shape, "Ycoordinates:",Ycoordinates_train.shape)
# Out:
# Length of train set Ycoordinates: (61, 2) Ycoordinates: (240, 2)

# %%
Zcoordinates_model=Sequential()

##### 0.77
# coordinates_model.add(Dense(3000,input_dim=1600,activation='relu'))
# coordinates_model.add(Dense(1500,activation='relu'))
# coordinates_model.add(Dense(600,activation='relu'))
# coordinates_model.add(Dropout(0.3))
# coordinates_model.add(Dense(2,activation='sigmoid'))
# coordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

Zcoordinates_model.add(Dense(3200,input_dim=1600,activation='relu'))
Zcoordinates_model.add(Dense(1600,activation='relu'))
Zcoordinates_model.add(Dense(300,activation='relu'))
Zcoordinates_model.add(Dropout(0.3))
Zcoordinates_model.add(Dense(2,activation='sigmoid'))
Zcoordinates_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['categorical_accuracy'])

# %%
Zcoordinates_model.fit(X_train,Zcoordinates_train,validation_data=(X_test,Zcoordinates_test),batch_size=25,epochs=10,verbose=1)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 2s 104ms/step - loss: 2.4906 - categorical_accuracy: 0.4515 - val_loss: 0.8499 - val_categorical_accuracy: 0.4918
# Epoch 2/10
# 10/10 [==============================] - 1s 86ms/step - loss: 0.8402 - categorical_accuracy: 0.4441 - val_loss: 0.7089 - val_categorical_accuracy: 0.5082
# Epoch 3/10
# 10/10 [==============================] - 1s 85ms/step - loss: 0.7082 - categorical_accuracy: 0.5488 - val_loss: 0.6988 - val_categorical_accuracy: 0.5082
# Epoch 4/10
# 10/10 [==============================] - 1s 84ms/step - loss: 0.7058 - categorical_accuracy: 0.4947 - val_loss: 0.6940 - val_categorical_accuracy: 0.5082
# Epoch 5/10
# 10/10 [==============================] - 1s 87ms/step - loss: 0.6968 - categorical_accuracy: 0.5484 - val_loss: 0.6959 - val_categorical_accuracy: 0.5082
# Epoch 6/10
# ...

# %%
index_in_Zcoord = 4
Zcoordinates_result=Zcoordinates_model.predict(X_test)
print(Zcoordinates_result[index_in_coord])
print(Zcoordinates[240 + index_in_coord])

Zcoordinates_inv = Zcoordinates_scaler.inverse_transform([Zcoordinates_result[index_in_Zcoord]])
print("Examples of coordinates_inv\n",Zcoordinates_inv[:1])
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2f9542830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [0.50264615 0.5036468 ]
# [-0.74265499 -5.66512861]
# Examples of coordinates_inv
#  [[-1.54443    -4.52519191]]

# %%
coordinates_full_inv = coordinates_scaler.inverse_transform(coordinates_result)
Ycoordinates_full_inv = Ycoordinates_scaler.inverse_transform(Ycoordinates_result)
Zcoordinates_full_inv = Zcoordinates_scaler.inverse_transform(Zcoordinates_result)
weight_full_inv = weight_scaler.inverse_transform(weight_result)
join_result = np.concatenate((coordinates_full_inv, Ycoordinates_full_inv, Zcoordinates_full_inv, weight_full_inv), axis = 1) # Zcoordinates_full_inv, weight_inv
#print(join_result)
#join_result = np.column_stack((join_result, weight_inv)) 
Y_full_inv = y_scaler.inverse_transform(result)
# print(Y_full_inv)

# %%
fig2 = plt.figure(1, figsize=(10,10))
ax2 = fig2.gca(projection='3d')

pos = 10
 # Give points 
x1 = [data_list[240 + pos][1][0], data_list[240 + pos][1][1]]
y1 = [data_list[240 + pos][1][2], data_list[240 + pos][1][3]]
z1 = np.array([data_list[240 + pos][1][4], data_list[240 + pos][1][5]]).flatten()

plt.xlim(0, 40)
plt.ylim(0, 40) 
 # Connect the first two points in the array

ax3 = fig2.gca(projection='3d')

 # Give points 
x2 = [join_result[pos][0], join_result[pos][1]]
y2 = [join_result[pos][2], join_result[pos][3]]
z2 = np.array([join_result[pos][4], join_result[pos][5]]).flatten()

ax4 = fig2.gca(projection='3d')

 # Give points 
x3 = [Y_full_inv[pos][0], Y_full_inv[pos][1]]
y3 = [Y_full_inv[pos][2], Y_full_inv[pos][3]]
z3 = np.array([Y_full_inv[pos][4], Y_full_inv[pos][5]]).flatten()

figure = ax2.plot(x1, y1, z1, c='r', )
figure = ax3.plot(x2, y2, z2, c='b', )
figure = ax4.plot(x3, y3, z3, c='g', )
plt.show()

print("weight: ", data_list[pos][1][6])
print("weight predicted: ", join_result[pos][6])
print("weight 7 elements predicted: ", Y_full_inv[pos][6])
# Out:
# weight:  10    2.850045
# Name: 6, dtype: float64
# weight predicted:  1.8711171
# weight 7 elements predicted:  0.61687505
